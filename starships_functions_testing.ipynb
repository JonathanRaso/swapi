# %%
import requests
import pandas as pd

# %%
def fetch_starships():
    uri = 'https://swapi.dev/api/starships/'
    myDict = {}
    data =[]
    pageMax = range(1,5)
    npage = 1
    for r in pageMax:
        myRequest = requests.get(uri+f"?page={npage}")
        if myRequest.status_code == 200:
            myDict[f"page{npage}"] = myRequest.json()
            data.append(myDict[f"page{npage}"]["results"])
        else:
            print("NO DATA")
            npage +=1
    return data

# %%
starships=fetch_starships()

# %%
def transform_starships_data(data):
    columns = ['name','model','starship_class','manufacturer','cost_in_credits','length','crew','passengers','max_atmosphering_speed','hyperdrive_rating','MGLT','cargo_capacity','consumables','films','pilots','url','created','edited']
    starships_df = pd.DataFrame(columns=columns)
    starships_count = 36
    indexDataFrame = 0
    for p in range (0,len(data)):
        for s in range(0,len(data[p])):
            starships_df.loc[indexDataFrame,'name'] = data[p][s]["name"]
            starships_df.loc[indexDataFrame,'model'] = data[p][s]["model"]
            starships_df.loc[indexDataFrame,'starship_class'] = data[p][s]["starship_class"]
            starships_df.loc[indexDataFrame,'manufacturer'] = data[p][s]["manufacturer"]
            starships_df.loc[indexDataFrame,'cost_in_credits'] = data[p][s]["cost_in_credits"]
            starships_df.loc[indexDataFrame,'length'] = data[p][s]["length"]
            starships_df.loc[indexDataFrame,'crew'] = data[p][s]["crew"]
            starships_df.loc[indexDataFrame,'passengers'] = data[p][s]["passengers"]
            starships_df.loc[indexDataFrame,'max_atmosphering_speed'] = data[p][s]["max_atmosphering_speed"]
            starships_df.loc[indexDataFrame,'hyperdrive_rating'] = data[p][s]["hyperdrive_rating"]
            starships_df.loc[indexDataFrame,'MGLT'] = data[p][s]["MGLT"]
            starships_df.loc[indexDataFrame,'cargo_capacity'] = data[p][s]["cargo_capacity"]
            starships_df.loc[indexDataFrame,'consumables'] = data[p][s]["consumables"]
            starships_df.loc[indexDataFrame,'films'] = data[p][s]["films"]
            starships_df.loc[indexDataFrame,'pilots'] = data[p][s]["pilots"]
            starships_df.loc[indexDataFrame,'url'] = data[p][s]["url"]
            starships_df.loc[indexDataFrame,'created'] = data[p][s]["created"]
            starships_df.loc[indexDataFrame,'edited'] = data[p][s]["edited"]
            indexDataFrame +=1
    return starships_df

# %%
transform_starships_data(starships)
# Out:
#                             name                            model  \
# 0                  CR90 corvette                    CR90 corvette
# 1                 Star Destroyer  Imperial I-class Star Destroyer
# 2   Sentinel-class landing craft     Sentinel-class landing craft
# 3                     Death Star      DS-1 Orbital Battle Station
# 4              Millennium Falcon          YT-1300 light freighter
# 5                         Y-wing                       BTL Y-wing
# 6                         X-wing                      T-65 X-wing
# 7                TIE Advanced x1      Twin Ion Engine Advanced x1
# 8                       Executor  Executor-class star dreadnought
# 9                Rebel transport           GR-75 medium transport
# 10                 CR90 corvette                    CR90 corvette
# 11                Star Destroyer  Imperial I-class Star Destroyer
# 12  Sentinel-class landing craft     Sentinel-class landing craft
# 13                    Death Star      DS-1 Orbital Battle Station
# 14             Millennium Falcon          YT-1300 light freighter
# 15                        Y-wing                       BTL Y-wing
# 16                        X-wing                      T-65 X-wing
# 17               TIE Advanced x1      Twin Ion Engine Advanced x1
# 18                      Executor  Executor-class star dreadnought
# 19               Rebel transport           GR-75 medium transport
# 20                 CR90 corvette                    CR90 corvette
# 21                Star Destroyer  Imperial I-class Star Destroyer
# 22  Sentinel-class landing craft     Sentinel-class landing craft
# 23                    Death Star      DS-1 Orbital Battle Station
# 24             Millennium Falcon          YT-1300 light freighter
# 25                        Y-wing                       BTL Y-wing
# 26                        X-wing                      T-65 X-wing
# 27               TIE Advanced x1      Twin Ion Engine Advanced x1
# 28                      Executor  Executor-class star dreadnought
# 29               Rebel transport           GR-75 medium transport
# 30                 CR90 corvette                    CR90 corvette
# 31                Star Destroyer  Imperial I-class Star Destroyer
# 32  Sentinel-class landing craft     Sentinel-class landing craft
# 33                    Death Star      DS-1 Orbital Battle Station
# 34             Millennium Falcon          YT-1300 light freighter
# 35                        Y-wing                       BTL Y-wing
# 36                        X-wing                      T-65 X-wing
# 37               TIE Advanced x1      Twin Ion Engine Advanced x1
# 38                      Executor  Executor-class star dreadnought
# 39               Rebel transport           GR-75 medium transport
#
#                      starship_class  \
# 0                          corvette
# 1                    Star Destroyer
# 2                     landing craft
# 3   Deep Space Mobile Battlestation
# 4                   Light freighter
# 5               assault starfighter
# 6                       Starfighter
# 7                       Starfighter
# 8                  Star dreadnought
# 9                  Medium transport
# 10                         corvette
# 11                   Star Destroyer
# 12                    landing craft
# 13  Deep Space Mobile Battlestation
# 14                  Light freighter
# 15              assault starfighter
# 16                      Starfighter
# 17                      Starfighter
# 18                 Star dreadnought
# 19                 Medium transport
# 20                         corvette
# 21                   Star Destroyer
# 22                    landing craft
# 23  Deep Space Mobile Battlestation
# 24                  Light freighter
# 25              assault starfighter
# 26                      Starfighter
# 27                      Starfighter
# 28                 Star dreadnought
# 29                 Medium transport
# 30                         corvette
# 31                   Star Destroyer
# 32                    landing craft
# 33  Deep Space Mobile Battlestation
# 34                  Light freighter
# 35              assault starfighter
# 36                      Starfighter
# 37                      Starfighter
# 38                 Star dreadnought
# 39                 Medium transport
#
#                                          manufacturer cost_in_credits  length  \
# 0                   Corellian Engineering Corporation         3500000     150
# 1                                    Kuat Drive Yards       150000000   1,600
# 2             Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3   Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                   Corellian Engineering Corporation          100000   34.37
# 5                              Koensayr Manufacturing          134999      14
# 6                                   Incom Corporation          149999    12.5
# 7                                Sienar Fleet Systems         unknown     9.2
# 8                  Kuat Drive Yards, Fondor Shipyards      1143350000   19000
# 9                               Gallofree Yards, Inc.         unknown      90
# 10                  Corellian Engineering Corporation         3500000     150
# 11                                   Kuat Drive Yards       150000000   1,600
# 12            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 13  Imperial Department of Military Research, Sien...   1000000000000  120000
# 14                  Corellian Engineering Corporation          100000   34.37
# 15                             Koensayr Manufacturing          134999      14
# 16                                  Incom Corporation          149999    12.5
# 17                               Sienar Fleet Systems         unknown     9.2
# 18                 Kuat Drive Yards, Fondor Shipyards      1143350000   19000
# 19                              Gallofree Yards, Inc.         unknown      90
# 20                  Corellian Engineering Corporation         3500000     150
# 21                                   Kuat Drive Yards       150000000   1,600
# 22            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 23  Imperial Department of Military Research, Sien...   1000000000000  120000
# 24                  Corellian Engineering Corporation          100000   34.37
# 25                             Koensayr Manufacturing          134999      14
# 26                                  Incom Corporation          149999    12.5
# 27                               Sienar Fleet Systems         unknown     9.2
# 28                 Kuat Drive Yards, Fondor Shipyards      1143350000   19000
# 29                              Gallofree Yards, Inc.         unknown      90
# 30                  Corellian Engineering Corporation         3500000     150
# 31                                   Kuat Drive Yards       150000000   1,600
# 32            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 33  Imperial Department of Military Research, Sien...   1000000000000  120000
# 34                  Corellian Engineering Corporation          100000   34.37
# 35                             Koensayr Manufacturing          134999      14
# 36                                  Incom Corporation          149999    12.5
# 37                               Sienar Fleet Systems         unknown     9.2
# 38                 Kuat Drive Yards, Fondor Shipyards      1143350000   19000
# 39                              Gallofree Yards, Inc.         unknown      90
#
#        crew passengers max_atmosphering_speed hyperdrive_rating MGLT  \
# 0    30-165        600                    950               2.0   60
# 1    47,060        n/a                    975               2.0   60
# 2         5         75                   1000               1.0   70
# 3   342,953    843,342                    n/a               4.0   10
# 4         4          6                   1050               0.5   75
# 5         2          0                 1000km               1.0   80
# 6         1          0                   1050               1.0  100
# 7         1          0                   1200               1.0  105
# 8   279,144      38000                    n/a               2.0   40
# 9         6         90                    650               4.0   20
# 10   30-165        600                    950               2.0   60
# 11   47,060        n/a                    975               2.0   60
# 12        5         75                   1000               1.0   70
# 13  342,953    843,342                    n/a               4.0   10
# 14        4          6                   1050               0.5   75
# 15        2          0                 1000km               1.0   80
# 16        1          0                   1050               1.0  100
# 17        1          0                   1200               1.0  105
# 18  279,144      38000                    n/a               2.0   40
# 19        6         90                    650               4.0   20
# 20   30-165        600                    950               2.0   60
# 21   47,060        n/a                    975               2.0   60
# 22        5         75                   1000               1.0   70
# 23  342,953    843,342                    n/a               4.0   10
# 24        4          6                   1050               0.5   75
# 25        2          0                 1000km               1.0   80
# 26        1          0                   1050               1.0  100
# 27        1          0                   1200               1.0  105
# 28  279,144      38000                    n/a               2.0   40
# 29        6         90                    650               4.0   20
# 30   30-165        600                    950               2.0   60
# 31   47,060        n/a                    975               2.0   60
# 32        5         75                   1000               1.0   70
# 33  342,953    843,342                    n/a               4.0   10
# 34        4          6                   1050               0.5   75
# 35        2          0                 1000km               1.0   80
# 36        1          0                   1050               1.0  100
# 37        1          0                   1200               1.0  105
# 38  279,144      38000                    n/a               2.0   40
# 39        6         90                    650               4.0   20
#
#    cargo_capacity consumables  \
# 0         3000000      1 year
# 1        36000000     2 years
# 2          180000     1 month
# 3   1000000000000     3 years
# 4          100000    2 months
# 5             110      1 week
# 6             110      1 week
# 7             150      5 days
# 8       250000000     6 years
# 9        19000000    6 months
# 10        3000000      1 year
# 11       36000000     2 years
# 12         180000     1 month
# 13  1000000000000     3 years
# 14         100000    2 months
# 15            110      1 week
# 16            110      1 week
# 17            150      5 days
# 18      250000000     6 years
# 19       19000000    6 months
# 20        3000000      1 year
# 21       36000000     2 years
# 22         180000     1 month
# 23  1000000000000     3 years
# 24         100000    2 months
# 25            110      1 week
# 26            110      1 week
# 27            150      5 days
# 28      250000000     6 years
# 29       19000000    6 months
# 30        3000000      1 year
# 31       36000000     2 years
# 32         180000     1 month
# 33  1000000000000     3 years
# 34         100000    2 months
# 35            110      1 week
# 36            110      1 week
# 37            150      5 days
# 38      250000000     6 years
# 39       19000000    6 months
#
#                                                 films  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 2                    [https://swapi.dev/api/films/1/]
# 3                    [https://swapi.dev/api/films/1/]
# 4   [https://swapi.dev/api/films/1/, https://swapi...
# 5   [https://swapi.dev/api/films/1/, https://swapi...
# 6   [https://swapi.dev/api/films/1/, https://swapi...
# 7                    [https://swapi.dev/api/films/1/]
# 8   [https://swapi.dev/api/films/2/, https://swapi...
# 9   [https://swapi.dev/api/films/2/, https://swapi...
# 10  [https://swapi.dev/api/films/1/, https://swapi...
# 11  [https://swapi.dev/api/films/1/, https://swapi...
# 12                   [https://swapi.dev/api/films/1/]
# 13                   [https://swapi.dev/api/films/1/]
# 14  [https://swapi.dev/api/films/1/, https://swapi...
# 15  [https://swapi.dev/api/films/1/, https://swapi...
# 16  [https://swapi.dev/api/films/1/, https://swapi...
# 17                   [https://swapi.dev/api/films/1/]
# 18  [https://swapi.dev/api/films/2/, https://swapi...
# 19  [https://swapi.dev/api/films/2/, https://swapi...
# 20  [https://swapi.dev/api/films/1/, https://swapi...
# 21  [https://swapi.dev/api/films/1/, https://swapi...
# 22                   [https://swapi.dev/api/films/1/]
# 23                   [https://swapi.dev/api/films/1/]
# 24  [https://swapi.dev/api/films/1/, https://swapi...
# 25  [https://swapi.dev/api/films/1/, https://swapi...
# 26  [https://swapi.dev/api/films/1/, https://swapi...
# 27                   [https://swapi.dev/api/films/1/]
# 28  [https://swapi.dev/api/films/2/, https://swapi...
# 29  [https://swapi.dev/api/films/2/, https://swapi...
# 30  [https://swapi.dev/api/films/1/, https://swapi...
# 31  [https://swapi.dev/api/films/1/, https://swapi...
# 32                   [https://swapi.dev/api/films/1/]
# 33                   [https://swapi.dev/api/films/1/]
# 34  [https://swapi.dev/api/films/1/, https://swapi...
# 35  [https://swapi.dev/api/films/1/, https://swapi...
# 36  [https://swapi.dev/api/films/1/, https://swapi...
# 37                   [https://swapi.dev/api/films/1/]
# 38  [https://swapi.dev/api/films/2/, https://swapi...
# 39  [https://swapi.dev/api/films/2/, https://swapi...
#
#                                                pilots  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   